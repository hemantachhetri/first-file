# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # ***Reading csv file***

# %%
set = pd.read_csv('/kaggle/input/dataset/CSV-bhu-key-indicators-2023.csv')
set
Remove= set.drop(set.index[0])
Remove
set.rename(columns={'Unnamed: 1': 'year'}, inplace=True)
set

# %%
set.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0                                       year   2000   2001  \
# 0           NaN                                 POPULATION    NaN    NaN
# 1           NaN      Total populationa as of 1 July ('000)  595.3  603.0
# 2           NaN           Population density (persons/km²)     15     15
# 3           NaN               Population (% annual change)    1.3    1.3
# 4           NaN  Urban populationb (% of total population)   21.0   21.0
# ..          ...                                        ...    ...    ...
# 377         NaN           Average terms of new commitments    NaN    NaN
# 378         NaN                Interest rate (% per annum)    3.6    1.1
# 379         NaN                           Maturity (years)   32.1   31.5
# 380         NaN                       Grace period (years)   10.5    8.8
# 381         NaN                          Grant element (%)   18.2   46.7
#
# ...

# %%
print (set. shape)
# Out:
# (0, 25)

# %%
print (set. columns)
# Out:
# Index(['Unnamed: 0', 'year', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
print (set.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   year        346 non-null    object
#  2   2000        300 non-null    object
#  3   2001        299 non-null    object
#  4   2002        300 non-null    object
#  5   2003        299 non-null    object
#  6   2004        299 non-null    object
#  7   2005        298 non-null    object
#  8   2006        299 non-null    object
#  9   2007        291 non-null    object
#  10  2008        300 non-null    object
#  11  2009        299 non-null    object
#  12  2010        299 non-null    object
#  13  2011        301 non-null    object
#  14  2012        301 non-null    object
#  15  2013        301 non-null    object
#  16  2014        301 non-null    object
#  17  2015        301 non-null    object
#  18  2016        301 non-null    object
# ...

# %% [markdown]
# #   ****1.Development Progress****

# %% [markdown]
# #  ****Employed****

# %%
progress= set.iloc[7]
progress
Remove= progress.drop(progress.index[0])
Remove
# Out:
# year    Employed
# 2000           …
# 2001       227.7
# 2002           …
# 2003       222.3
# 2004     210.5 |
# 2005     249.0 |
# 2006       222.1
# 2007       274.1
# 2008           …
# 2009       312.7
# 2010       320.9
# 2011       323.7
# 2012       329.5
# 2013       335.9
# 2014       339.6
# 2015       344.3
# 2016     347.1 |
# 2017     332.1 |
# 2018       300.4
# 2019       311.1
# 2020       314.6
# 2021       322.1
# 2022       287.8
# Name: 7, dtype: object

# %%
years = [2001, 2003, 2005, 2006, 2007, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
inputs = [227.7, 222.3, 249.0, 222.1, 274.1, 312.7, 320.9, 323.7, 329.5, 335.9, 339.6, 344.3, 347.1, 332.1, 300.4, 311.1, 314.6, 322.1, 287.8]

plt.plot(years, inputs, marker='o')

plt.xlabel('No.of years')
plt.ylabel('No.of Employment')
plt.title('Line graph for Employees being Employed')
plt.show()

# %% [markdown]
# In this line graph the x-axis shows the number of years and the y-axis shows the number of employment. The line that has been a consistent rise in the number of employees throughout time. This implies that there has been development and expansion inside the organization or sector. The number of employees has slightly decline in 2015, which would point to a adjustment. It is difficult to pinpoint the precise causes of this decline in the absence of more information. More details regarding the business that might have impacted the variations in the workforce would be beneficial. There is a chance of increasing the employed rate in future.

# %% [markdown]
# # **Imports of goods and services**

# %%
progress= set.iloc[140]
progress
Remove= progress.drop(progress.index[0])
Remove
# Out:
# year         Less: Imports of goods and services
# 2000                                     9,529.9
# 2001                                    10,379.5
# 2002                                    12,152.2
# 2003                                    13,612.8
# 2004                                    17,495.4
# 2005                                    19,767.4
# 2006                                    19,349.2
# 2007                                    21,470.8
# 2008                                    22,061.5
# 2009                                    25,226.3
# 2010                                    32,475.4
# 2011                                    34,410.8
# 2012                                    31,959.2
# 2013                                    31,388.7
# 2014                                    30,361.5
# 2015                                    34,454.7
# 2016                                    32,172.3
# 2017                                    32,044.4
# ...

# %%
years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
         '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

imports = [9529.9, 10379.5, 12152.2, 13612.8, 17495.4, 19767.4, 19349.2, 21470.8, 22061.5, 25226.3, 32475.4, 34410.8,
           31959.2, 31388.7, 30361.5, 34454.7, 32172.3, 32044.4, 34150.3, 32030.4, 28064.3, 32482]

plt.bar(years, imports)

plt.xlabel('No. of years')
plt.ylabel('No. for imports of goods and services')
plt.title('Imports of goods and services from 2000 to 2021')

plt.xticks(rotation=100)
plt.tight_layout()
plt.show()

# %% [markdown]
# In this bar graph x and y axis shows the number of years and the number for import of goods and services. Graph implies increase in the import of goods and services over a period of time. Number of import of goods and services has been constant since 2010 to 2021 that indicate progress in development in our country.

# %% [markdown]
# # ****Exports of goods and services****

# %%
progress= set.iloc[74]
progress
Remove= progress.drop(progress.index[0])
Remove
# Out:
# year         Exports of goods and services
# 2000                               5,797.8
# 2001                               5,909.0
# 2002                               6,231.9
# 2003                               7,396.8
# 2004                               9,880.9
# 2005                              13,812.8
# 2006                              22,134.3
# 2007                              27,185.6
# 2008                              26,709.7
# 2009                              27,366.5
# 2010                              30,777.0
# 2011                              35,003.7
# 2012                              37,739.4
# 2013                              42,636.4
# 2014                              43,589.9
# 2015                              44,261.7
# 2016                              42,966.2
# 2017                              48,004.3
# 2018                              51,570.3
# 2019                              60,602.2
# 2020                              51,109.6
# ...

# %%
years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
exports = [5797.8, 5909.0, 6231.9, 7396.8, 9880.9, 13812.8, 22134.3, 27185.6, 26709.7, 27366.5, 30777.0, 35003.7, 37739.4, 42636.4, 43589.9, 44261.7, 42966.2, 48004.3, 51570.3, 60602.2, 51109.6, 59759.4, 0]

plt.bar(years, exports)

plt.xlabel('No. of years')
plt.ylabel('No. of exports of goods and services')
plt.title('Bar graph for Export of goods and services ')

plt.xticks(rotation=100)
plt.show()

# %% [markdown]
# The graph's horizontal bar arrangement denotes that, years is represented by the x-axis and the number of export of goods and services is represented by the y-axis. The number of bars on the graph increases steadily every year, indicating a growing or positive trend. The increase in export of goods and services shows that the country is developing  and a indication of independent too.

# %% [markdown]
# # *M2y (% of GDP at current market prices)*

# %%
progress=set.iloc[223]
progress
Remove= progress.drop(progress.index[0])
Remove
# Out:
# year                   M2y (% of GDP at current market...
# 2000                                                 52.6
# 2001                                                 49.6
# 2002                                                 54.8
# 2003                                                 59.5
# 2004                                                 56.2
# 2005                                                 55.6
# 2006                                                 62.1
# 2007                                                 57.3
# 2008                                                 50.7
# 2009                                                 56.8
# 2010                                                 64.0
# 2011                                                 65.9
# 2012                                                 49.1
# 2013                                                 59.6
# 2014                                                 57.8
# ...

# %%
years = ['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
inputs = [52.6, 49.6, 54.8, 59.5, 56.2, 55.6, 62.1, 57.3, 50.7, 56.8, 64.0, 65.9, 49.1, 59.6, 57.8, 55.8, 57.8, 68.3, 70.3, 70.2, 82.6, 100.2, 103.0]

plt.pie(inputs, labels=years, autopct='%1.1f%%')

plt.title('GDP at current market')

plt.axis('equal')
plt.show()

# %% [markdown]
# This pie chart have been variations over the years in the money supply as a percentage of GDP at current market values. It was rather stable in 2008 financial crisis, demonstrating a proportionate increase in the money supply in relation to the size of the economy. However, the money supply as a proportion of GDP fell throughout the crisis, indicating a decline in the money supply. After the crisis, there was a slow but steady recovery, and by 2010, the money supply had surpassed pre-crisis levels. There were variations in the money supply as a percentage of GDP between 2010 and 2022, which suggests shifting monetary conditions and a sign of development.

# %% [markdown]
# #   **2. Economic Growth**

# %% [markdown]
# #    Financial and insurance activities

# %%
growth= set.iloc[17]
growth
Remove=growth.drop(growth.index[0])
Remove
# Out:
# year         Financial and insurance activitiesi
# 2000                                           …
# 2001                                         2.1
# 2002                                           …
# 2003                                         0.2
# 2004                                       2.4 |
# 2005                                       2.3 |
# 2006                                         1.3
# 2007                                         NaN
# 2008                                           …
# 2009                                         1.0
# 2010                                         2.4
# 2011                                         2.3
# 2012                                         2.4
# 2013                                         2.9
# 2014                                         2.7
# 2015                                         2.5
# 2016                                       3.3 |
# 2017                                       2.8 |
# ...

# %%
years = [2001, 2003, 2004, 2005, 2006, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
inputs = [2.1, 0.2, 2.4, 2.3, 1.3, 1.0, 2.4, 2.3, 2.4, 2.9, 2.7, 2.5, 3.3, 2.8, 2.6, 3.0, 2.9, 3.1, 3.7]
plt.scatter(years, inputs)

plt.title('Scatter Plot for Finance and Insurance Activities')
plt.xlabel('No. of years')
plt.ylabel('No. of input for Finamce and Insurance')
plt.show()

# %% [markdown]
# In this scatter plot x-axis and y-axis shows the number of years and the number of input of finance and insurance. The percentage growth rates of the insurance and finance industries between 2000 and 2022 increases accordingly. The data displays varying growth rates across years, with some years having slower growth and others having faster economic growth.

# %% [markdown]
# #  **Gross capital formation**

# %%
growth= set.iloc[67]
growth
Remove= growth.drop(growth.index[0])
Remove
# Out:
# year         Gross capital formation
# 2000                         9,603.3
# 2001                        13,624.7
# 2002                        15,727.8
# 2003                        17,076.8
# 2004                        20,568.3
# 2005                        18,990.7
# 2006                        19,072.3
# 2007                        14,508.9
# 2008                        23,494.7
# 2009                        28,000.6
# 2010                        44,738.7
# 2011                        57,467.1
# 2012                        66,128.7
# 2013                        48,554.8
# 2014                        62,193.5
# 2015                        71,287.0
# 2016                        83,081.8
# 2017                        83,124.2
# 2018                        79,682.1
# 2019                        67,609.8
# 2020                        56,995.6
# 2021                        67,276.8
# 2022                               …
# Name: 67, dtype: object

# %%
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
inputs = [9603.3, 13624.7, 15727.8, 17076.8, 20568.3, 18990.7, 19072.3, 14508.9, 23494.7, 28000.6, 44738.7, 57467.1, 66128.7, 48554.8, 62193.5, 71287.0, 83081.8, 83124.2, 79682.1, 67609.8, 56995.6, 67276.8]
plt.plot(years, inputs, '-o')

plt.xlabel('No. of yeasr')
plt.ylabel('No. of inputs')
plt.title('Line graph for Grodss Capital Formation')

plt.show()

# %% [markdown]
# This is line grapg showing number of years in x-axis and number of inputs in y-axis. The data on Gross Capital Formation shows the overall amount of investments made in an economy over a given time frame. The data indicates a generally rising trend in investment activity. Gross Capital Formation significantly grew between 2010 and 2017, indicating strong economic growth and higher investment.We can see in future there will be increase in economical growth.

# %% [markdown]
# # **Restaurants and hotels**

# %%
growth= set.iloc[196]
growth
Remove= growth.drop(growth.index[0])
Remove
# Out:
# year              Restaurants and hotels
# 2000                                   …
# 2001                                   …
# 2002                                   …
# 2003                                41.1
# 2004                                43.5
# 2005                                45.6
# 2006                                48.2
# 2007                                48.5
# 2008                                51.7
# 2009                                52.5
# 2010                                56.2
# 2011                                61.4
# 2012                                66.4
# 2013                                75.9
# 2014                                78.5
# 2015                                84.3
# 2016                                87.0
# 2017                                89.1
# 2018                                94.3
# 2019                                99.4
# 2020                               101.0
# 2021                               107.5
# ...

# %%
years = ['2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
inputs = [41.1, 43.5, 45.6, 48.2, 48.5, 51.7, 52.5, 56.2, 61.4, 66.4, 75.9, 78.5, 84.3, 87, 89.1, 94.3, 99.4, 101, 107.5, 111.3]

plt.bar(years, inputs)

plt.xlabel('No. of years')
plt.ylabel('No. of restaurants and hotels')
plt.title('Bar graph for Restaurants and Hotels')

plt.xticks(rotation=100)
plt.show()

# %% [markdown]
# The bar graph shows the number of hotels and restaurants from 2003 to 2022. A continuous increase in the number of establishments throughout year is indicated by the graph's upward trend. The industry experienced a notable expansion from 2008 to 2019, with the growth rate picking up speed from its initial modest pace. The growth rate has been consistent but somewhat less noticeable in recent years. All things considered, which is good news for the restaurants and hotels sector in future where there will be more growth.

# %% [markdown]
# # **Manufacturing**

# %%
growth= set.iloc[95]
growth
Remove= growth.drop(growth.index[0])
Remove
# Out:
# year         Manufacturing
# 2000               1,618.9
# 2001               1,820.6
# 2002               1,855.2
# 2003               1,967.3
# 2004               2,055.0
# 2005               2,214.4
# 2006               2,468.7
# 2007               3,086.8
# 2008               3,349.4
# 2009               3,579.9
# 2010               4,302.4
# 2011               4,616.4
# 2012               4,929.7
# 2013               4,670.7
# 2014               5,098.8
# 2015               5,323.9
# 2016               5,452.9
# 2017               5,805.0
# 2018               5,956.4
# 2019               5,956.1
# 2020               4,719.6
# 2021               4,846.7
# 2022                     …
# Name: 95, dtype: object

# %%
years= [ 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
inputs= [ 1618.9, 1820.6, 1855.2, 1967.3, 2055.0, 2214.4, 2468.7, 3086.8, 3349.4, 3579.9, 4302.4, 4616.4, 4929.7, 4670.7, 5098.8, 5323.9, 5452.9, 5805.0, 5956.4, 5956.1, 4719.6, 4846.7]
plt.scatter(years, inputs)

plt.title('Scatter Plot for manufacturing')
plt.xlabel('No. of years')
plt.ylabel('Input for manufacture')
plt.show()

# %% [markdown]
# This scatter plot shows the economic prosperity and industry expansion was reflected in the manufacturing output's noticeable increase from 2000 to 2006.The manufacturing production saw a little moves downward in 2021, suggesting that the industry is resilient. That year's performance is uncertain, though, as 2022's data is not given. Manufacturing is also one of the key factor, that shows there is a economic growth in our country.

# %% [markdown]
# #  **3. Sectoral Contributions**

# %% [markdown]
# # **Education**

# %%
sector=set.iloc[195]
sector
Remove=sector.drop(sector.index[0])
Remove
# Out:
# year              Education
# 2000                      …
# 2001                      …
# 2002                      …
# 2003                   70.8
# 2004                   70.8
# 2005                   70.8
# 2006                   70.8
# 2007                   70.8
# 2008                   70.8
# 2009                   70.8
# 2010                   70.8
# 2011                   70.8
# 2012                   70.8
# 2013                   76.2
# 2014                   81.5
# 2015                   86.8
# 2016                   92.8
# 2017                   96.2
# 2018                   99.4
# 2019                  100.6
# 2020                  104.1
# 2021                  104.7
# 2022                  106.4
# Name: 195, dtype: object

# %%
years = ['2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
inputs = [70.8, 70.8, 70.8, 70.8, 70.8, 70.8, 70.8, 70.8, 70.8, 70.8, 76.2, 81.5, 86.8, 92.8, 96.2, 99.4, 100.6, 104.1, 104.7, 106.4]

plt.pie(inputs, labels=years, autopct='%1.1f%%')

plt.title('Education')

plt.axis('equal')
plt.show()

# %% [markdown]
# We can get an information about education from this pie chart. The productivity levels increases in the education industry over time. The productivity level stayed constant at 70.8 from 2003 to 2019. But productivity began to rise in 2019, and by 2022, it had increased.The education sector may be becoming more efficient and producing more as seen by the rising productivity levels. A greater emphasis on student outcomes, modifications to teaching strategies, improvements to the curriculum, or developments in educational technology could all be contributing causes to sectoral.

# %% [markdown]
# # **Transport**

# %%
sector= set.iloc[192]
sector
Remove= sector.drop(sector.index[0])
Remove
# Out:
# year              Transport
# 2000                      …
# 2001                      …
# 2002                      …
# 2003                   45.4
# 2004                   47.6
# 2005                   49.7
# 2006                   52.8
# 2007                   53.6
# 2008                   60.9
# 2009                   63.1
# 2010                   65.4
# 2011                   73.0
# 2012                   75.9
# 2013                   78.9
# 2014                   85.5
# 2015                   92.8
# 2016                   96.3
# 2017                   98.1
# 2018                   97.4
# 2019                  100.1
# 2020                  100.6
# 2021                  108.0
# 2022                  121.6
# Name: 192, dtype: object

# %%
years = ['2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
inputs = [45.4, 47.6, 49.7, 52.8, 53.6, 60.9, 63.1, 65.4, 73, 75.9, 78.9, 85.5, 92.8, 96.3, 98.1, 97.4, 100.1, 100.6, 108, 121.6]

plt.bar(years, inputs)

plt.xlabel('No. of years')
plt.ylabel('Input for transport')
plt.title('Bar graph for Transport')

plt.xticks(rotation=100)
plt.show()

# %% [markdown]
# The given data shown in the bar graph is the levels of transportation across years. There was a stable rise in transport levels, with slight annual increases, from 2003 to 2012. Nonetheless, there was a notable acceleration in the transport levels beginning in 2013, which resulted in a notable rise in the index by 2022.The promising trend of development and expansion in the transportation industry.The transportation levels suggests better connectedness, increased mobility, and possible economic advantages. Booming transportation industry that promotes business, trade, and general progress is there.

# %% [markdown]
# # **Health**

# %%
sector= set.iloc[191]
sector
Remove= sector.drop(sector.index[0])
Remove
# Out:
# year              Health
# 2000                   …
# 2001                   …
# 2002                   …
# 2003                59.6
# 2004                61.1
# 2005                63.3
# 2006                65.8
# 2007                68.6
# 2008                72.8
# 2009                74.6
# 2010                75.5
# 2011                79.9
# 2012                85.3
# 2013                90.1
# 2014                91.7
# 2015                94.2
# 2016                95.0
# 2017                96.0
# 2018                97.9
# 2019               100.3
# 2020               103.8
# 2021               108.3
# 2022               112.8
# Name: 191, dtype: object

# %%
years = [2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
inputs = [59.6, 61.1, 63.3, 65.8, 68.6,72.8, 74.6, 75.5, 79.9, 85.3, 90.1, 91.7, 94.2, 95, 96, 97.9, 100.3, 103.8, 108.3, 112.8 ]
plt.plot(years, inputs, '-o')

plt.xlabel('No. of years')
plt.ylabel('No. of health')
plt.title('Line graph for Health')

plt.show()

# %% [markdown]
# The line graph is for health sector where the data indicates that health levels have generally been improving over year. From 2003 to 2012, there were progressively better years, and from 2013 to 2022, there was further advancement. These beneficial developments were probably influenced by better public health programs, healthcare services, and socioeconomic considerations. Rising health levels point to possible advantages like lower death rates, longer life spans, and better general wellbeing for people and communities. Health care is one of the best sectoral contribuation in our country Bhutan. There is always a positive graph for this sector.

# %% [markdown]
# # **Recreation and culture**

# %%
sector= set.iloc[194]
sector
Remove= sector.drop(sector.index[0])
Remove
# Out:
# year              Recreation and culture
# 2000                                   …
# 2001                                   …
# 2002                                   …
# 2003                                43.9
# 2004                                44.3
# 2005                                44.4
# 2006                                47.7
# 2007                                51.5
# 2008                                55.3
# 2009                                56.0
# 2010                                58.5
# 2011                                77.7
# 2012                                87.0
# 2013                                95.5
# 2014                                97.4
# 2015                                98.6
# 2016                                98.0
# 2017                                99.2
# 2018                                99.6
# 2019                                99.9
# 2020                               100.0
# 2021                               102.3
# ...

# %%
years = [ 2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
inputs = [43.9, 44.3, 44.4, 47.7, 51.5, 55.3, 56, 58.5, 77.7, 87, 95.5, 97.4, 98.6, 98, 99.2, 99.6, 99.9, 100, 102.3, 104.1 ]
plt.scatter(years, inputs)

\plt.title('Scatter Plot for Recreation and Culture')
plt.xlabel('No. of years')
plt.ylabel('No. of inputs')
plt.show()

# %% [markdown]
# This scatter plot shows, as indicated by the number of inputs, the levels of culture and recreation across year. The information demonstrates a rising tendency in leisure and culture over years. From 2003 through 2012, there were progressively better year, and from 2013 through 2022, there was further expansion. This calls for more leisure year, cultural interaction, and resource access. Growing levels of culture and recreation point to possible advantages including better quality of life, increased community involvement, and possible financial gains from the tourism and cultural sectors.

# %% [markdown]
# # **4. Fiscal Sustainability and External Sector**

# %% [markdown]
# # **Total Revenue**

# %%
fiscal= set.iloc[254]
fiscal
Remove= fiscal.drop(fiscal.index[0])
Remove
# Out:
# year                       Total revenue
# 2000                                23.2
# 2001                                22.1
# 2002                                19.5
# 2003                                16.5
# 2004                                15.9
# 2005                                17.0
# 2006                                17.3
# 2007                                20.4
# 2008                                22.6
# 2009                                27.6
# 2010                                27.4
# 2011                                23.0
# 2012                                22.6
# 2013                                21.3
# 2014                                21.5
# 2015                                21.4
# 2016                                19.8
# 2017                                19.5
# 2018                                22.8
# 2019                                18.2
# 2020                                21.8
# 2021                                24.9
# ...

# %%
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
inputs = [23.2, 22.1, 19.5, 16.5, 15.9, 17, 17.3, 20.4, 22.6, 27.6, 27.4, 23, 22.6, 21.3, 21.5, 21.4, 19.8, 19.5, 22.8, 18.2, 21.8, 24.9, 21.3]
plt.scatter(years, inputs)

plt.title('Scatter Plot for Total Revenue')
plt.xlabel('No. of years')
plt.ylabel('Input for revenue')
plt.show()

# %% [markdown]
# This scatter plot is about revenue over the years, is represented by the data that is provided. Revenue levels fluctuate, seeing increases and decreases over year. From the available statistics alone, it is hard to draw any definitive conclusions about fiscal stability. Other financial metrics and the overall economic environment must be taken into account in order to fully evaluate fiscal stability.

# %% [markdown]
# # **Current expenditure**

# %%
fiscal= set.iloc[242]
fiscal
Remove=fiscal.drop(fiscal.index[0])
Remove
# Out:
# year                   Current expenditure
# 2000                               3,702.1
# 2001                               4,435.6
# 2002                               4,467.9
# 2003                               4,580.9
# 2004                               5,149.2
# 2005                               6,170.6
# 2006                               6,672.4
# 2007                               7,636.2
# 2008                               9,725.7
# 2009                              11,061.4
# 2010                              12,902.7
# 2011                              14,735.1
# 2012                              16,705.6
# 2013                              18,096.5
# 2014                              17,941.2
# 2015                              21,032.0
# 2016                              22,880.6
# 2017                              24,129.6
# 2018                              27,494.7
# 2019                              27,768.7
# 2020                              35,525.4
# ...

# %%
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
data = [3702.1, 4435.6, 4467.9, 4580.9, 5149.2, 6170.6, 6672.4, 7636.2, 9725.7, 11061.4, 12902.7, 14735.1, 16705.6, 18096.5, 17941.2, 21032.0, 22880.6, 24129.6, 27494.7, 27768.7, 35525.4, 43515.8, 34444.7]

plt.bar(years, inputs)

plt.xlabel('No. of years')
plt.ylabel('Input for expenditure')
plt.title('Bar graph for Current Expenditure')

plt.xticks(rotation=100)
plt.show()

# %% [markdown]
# In this bar graph the data indicates a tendency of increasing current expenditure over year, with more spending on social welfare, infrastructure, public services, and administrative costs, among other sectors. Still, it is difficult to draw firm conclusions on fiscal stability from the available statistics in the absence of information on revenue and other financial indicators. Beyond income patterns and debt levels, budgetary management, and the broader economic environment, further aspects must be taken into account in order to assess fiscal stability thoroughly.

# %% [markdown]
# # **Current surplus/deficit**

# %%
fiscal= set.iloc[245]
Remove= fiscal.drop(fiscal.index[0])
Remove
# Out:
# year         Current surplus/deficit
# 2000                           607.6
# 2001                           159.9
# 2002                           597.5
# 2003                           179.3
# 2004                          -167.6
# 2005                          -337.1
# 2006                            62.7
# 2007                         2,270.7
# 2008                         2,535.9
# 2009                         2,891.2
# 2010                         2,642.3
# 2011                         2,630.4
# 2012                         3,543.0
# 2013                         2,916.3
# 2014                         5,221.1
# 2015                         3,998.9
# 2016                         5,032.8
# 2017                         5,390.7
# 2018                         9,352.0
# 2019                         6,914.1
# 2020                           615.1
# 2021                        -7,741.3
# 2022                         4,176.4
# Name: 245, dtype: object

# %%
years= [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
inputs: [607.6, 159.9, 597.5, 179.3, -167.6, -337.1, 62.7, 2270.7, 2535.9, 2891.2, 2642.3, 2630.4, 3543.0, 2916.3, 5221.1, 3998.9, 5032.8, 5390.7, 9352.0, 6914.1, 615.1, -7741.3, 4176.4]
plt.plot(years, inputs, '-o')

plt.xlabel('No. of years')
plt.ylabel('No. of inputs')
plt.title('Line graph for Current surplus/ deficit')

plt.show()

# %% [markdown]
# The information in this line graph illustrates the entity's financial situation at each point in years by displaying the present surplus/deficit across year. The surplus/deficit figures fluctuate, with some years displaying surpluses and others displaying losses. Over year, the evidence points to a mix of favorable and unfavorable financial conditions. Additional investigation is required to determine the fundamental causes of these variations and to evaluate the entity's overall financial performance and stability.

# %% [markdown]
# # **Domestic borrowing and Foreign borrowing**

# %%
fiscal= set.iloc[[249, 250]]
fiscal
# Out:
#       x                          year   2000     2001     2002     2003  \
# 249 NaN            Domestic borrowing      –        –    500.0    250.0
# 250 NaN             Foreign borrowing  606.6  1,056.7  1,396.7  1,537.3
#
#        2004     2005    2006    2007  ...    2013    2014    2015      2016  \
# 249  -250.0  1,753.0  -500.0  -175.3  ...  -175.3  -175.3  -175.3    -183.8
# 250   932.1    739.4   715.5   530.1  ...   667.6  -867.0  -911.1  -1,031.6
#
#       2017   2018     2019     2020     2021     2022
# 249   -9.2   -9.9    323.9   -882.4  8,907.3  7,267.6
# 250  533.5  -92.1  1,101.1  3,527.1  1,486.9  4,086.7
#
# [2 rows x 25 columns]

# %%
years = (2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022)
D_borrowing = [0, 0, 500, 250, -250, 1753, -500, -175.3, -175.3, -175.3, -175.3, -183.8, -9.2, -9.9, 323.9, -882.4, 8907.3, 7267.6]
F_borrowing = [606.6, 1056.7, 1396.7, 1537.3, 932.1, 739.4, 715.5, 530.1, 667.6, -867, -911.1, -1031.6, 533.5, -92.1, 1101.1, 3527.1, 1486.9, 4086.7]

plt.figure(figsize=(12, 6))
plt.plot(years, D_borrowing, label='Domestic borrowing', marker= 'o')
plt.plot(years, F_borrowing, label='Foreign borrowing', marker='o')

plt.xlabel('No. of years')
plt.ylabel('Borrowing amount')
plt.title('Line graph for Domestic  and Foreign borrowing')

plt.legend()
plt.show()

# %% [markdown]
# This line graph shows the information on both domestic and foreign borrowing throughout year is included in the data supplied. The sums borrowed, both from abroad and domestically, fluctuate and are recorded at different values. It is challenging to evaluate the effect of borrowing on fiscal stability, in the absence of more details and context. A full assessment of fiscal stability necessitates taking into account variables including income, spending, debt levels, and the state of the economy.
